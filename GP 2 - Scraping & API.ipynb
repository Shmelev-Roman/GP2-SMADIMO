# %% [markdown]
# # Современные методы анализа данных и машинного обучения, БИ
#
# ## НИУ ВШЭ, 2024-25 учебный год

# %% [markdown]
# ## Групповой проект №2. DE: Scraping & API

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Дата выдачи:__ 21.02.2025
#
# __Защита проекта:__ 05.03.2025

# %% [markdown]
# ## Формат выполнения

# %% [markdown]
# Групповой проект представляет собой творческое инициативное групповое задание, которое выполняется студентами в командах от 3 до 6 человек. В то же время, следует помнить, что чем больше в команде людей, тем выше предъявляются требования в целом к команде, а также к выполняему ею проекту. Команды разрешается формировать из студентов разных групп.
#
# При оценивании результатов выполнения проекта командой, в обязательном порядке проверяется и учитывается в оценке вклад ***каждого участника*** в общую работу команды. Вследствие этого, крайне важно ответственно подойти к выбору сокомандников, распределению обязанностей внутри команды, а также пресечению наличия "мертвых душ" в команде.
#
# При необходимости, команда большинством голосов имеет право исключить человека из команды *до защиты проекта*, сообщив об этом преподавателю, в случае если такой человек никак не проявлялся в ходе выполнения проекта и являлся как раз таки той самой "мертвой душой". Помните про эту возможность, поскольку наличие "мертвых душ" может негативно повлиять на качество и оценку для всего проекта и, как следствие, в целом для всей команды!
#
# Запись составов команд осуществляется по ссылке в таблице:
#
# https://docs.google.com/spreadsheets/d/1aUFah0NgORUzjMoA6QxKt7OyVN5djf1Vvq3vB1bbx8k/edit?usp=sharing

# %% [markdown]
# ## Оценивание и штрафы

# %% [markdown]
# Групповой проект оценивается исходя из устной защиты (презентации) командой выполненного ими проекта перед комиссией. Комиссия составляется из преподавателей курса, ассистентов курса, а также приглашенных экспертов из индустрии.
#
# В рамках каждой защиты комиссия выставляет два типа оценок.
#
# Первая оценка — это оценка для всего проекта в целом. Она ставится комиссией, исходя из глубины проработки командой предметной области, сложности применяемых в проекте инструментов, а также прочих аспектов, связанных с содержанием выполняемого в проекте ТЗ. При выставлении этой оценки комиссия ориентируется на критерии, более подробно представленные ниже в разделе "Критерии оценки проекта".
#
# Вторая оценка — это индивидуальная оценка каждого участника команды. Именно эта оценка выставляется впоследствии в ведомость. Индивидуальная оценка участника команды определяется комиссией, исходя из того, насколько участник ориентируется в выполненном командой проекте, как он отвечает на адресованные персонально ему вопросы комиссии, насколько в принципе прослеживается его роль в проекте, а также исходя из других аспектов, связанных с участием конкретного человека в деятельности команды. Индивидуальная оценка не может превосходить оценку команды за проект в целом (первую оценку), однако, в случае когда участник спокойно и корректно отвечает на все адресованные ему вопросы, свободно ориентируется в материале и содержании выполненного проекта, а также когда его роль в работе команды не вызывает сомнений, — в таком случае, индивидуальная оценка участника становится равной оценке для всего проекта (т.е. в идеальном случае — вторая оценка равна первой оценке). Кроме того, в исключительных случаях, при демонстрации участником на защите превосходящих ожидания уровней понимания, участия и вовлечения в рамках проекта, комиссия может своим решением повысить индивидуальную оценку для этого участника на 0,5 или 1 балл относительно общей оценки за проект (первой оценки).
#
# Во избежание субъективности и/или предвзятости оценки тех или иных членов комиссии в отношении тех или иных команд, а также каких-либо иных проявлений неравных условий — распределение команд между комиссиями осуществляется абсолютно рандомно с использованием средств библиотеки Numpy :)) — в качестве рэндом сида выступает дата, в которую производится распределение, например, `np.random.seed(21022025)`.
#
# Обратите, пожалуйста, внимание на то, что бОльшая часть комиссий осуществляет приём проектов в очной форме, однако могут присутствовать и 1-2 комиссии, которые будут работать дистанционно с использованием средств видеосвязи. В случае попадания команды путем случайного распределения в комиссию, работающую в очной форме, *не допускается* какое-либо изменение формата проведения для команды на онлайн-режим, равно как и любые другие перемещения команд между комиссиями (смены комиссий), для сохранения честности и непредвзятости случайного распределения.
#
# Явка студента на защиту проекта является обязательной; вклад студента без его присутствия не оценивается и автоматически является равным нулю. Для дистанционных комиссий, дополнительным требованием является обязательное наличие включенной камеры в течение всего времени нахождения в конференции

# %% [markdown]
# ## Описание задания

# %% [markdown]
# В современном мире данных эффективный сбор и интеграция информации из различных источников являются фундаментом для принятия обоснованных решений и успешного ведения бизнеса. Компании, стремясь к конкурентоспособности, активно используют технологии веб-скрапинга и взаимодействия с API для автоматизации процесса сбора данных, обеспечения их актуальности и полноты.
#
# В данном проекте вы на реальных данных попрактикуетесь в том, как осуществляется веб-скрапинг различных сайтов для извлечения необходимой информации, а также в работе с API популярных сервисов для получения структурированных данных. Вы научитесь применять современные инструменты и библиотеки, отражающие различные этапы DE, обрабатывать и очищать полученную информацию, а также интегрировать данные из различных источников для последующего использования их в аналитических и бизнес-задачах.

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# В рамках этого проекта вы сами найдете датасет, с которым будете работать. Точнее, не найдете, а... соберёте его самостоятельно на основе источников!
#
# Итак, начните с того, что выберите два сайта/портала со схожей тематикой (например, NYT и Bloomberg). Их тематика должна позволять в дальнейшем объединить данные в единую таблицу. Один из этих двух сайтов нужно будет обработать с помощью средств Web-Scraping'a и Data Parsing'a; другой же — используя API.
#
# Определившись с источниками, непосредственно проделайте скачивание данных путём скрейпинга и методами API соответственно и затем объедините всё в финальный датасет. Обязательным требованием к датасету является также наличие в нём как минимум одного столбца с текстовыми данными: описание, состав, комментарии о чём-либо, текст заметки/новости, или что-то ещё.
#
# Кроме того, разумеется, следует помнить, что полученный датасет должен, конечно, быть осмысленным с бизнес-точки зрения и потенциально позволять решать какую-то конкретную бизнес-задачу. Это как минимум означает, что каждому объекту, имеющему своё признаковое пространство — в том числе с текстовым признаком, — должно также соответствовать значение некоторой целевой переменной, которая является релевантной в рамках выбранной вами предметной области.

# %% [markdown]
# Примеры задач, которые мы можем предложить вам в качестве источника для вдохновения — пожалуйста, ни в коем случае не воспринимайте это как исчерпывающий список — это действительно всего лишь примеры:
#
# * Сайт новостей: текстовый столбец — сама новость; признаки — различные характеристики новости: автор, дата публикации, тип новости и т.д.; целевая переменная — количество просмотров новости (можно поделить на число дней с момента даты публикации, чтобы получить «среднее число просмотров в день», что ещё нагляднее)
#
# * Сайт с товарами/книгами/фильмами: текстовый столбец — описание товара/книги/фильма; признаки — различные характеристики объекта: цена, год производства/выпуска, компания-производитель и т.д.; целевая переменная — средний рейтинг объекта
#
# * Блоги: текстовый столбец — тексты заметок; признаки — различные характеристики заметки: автор, время публикации, количество прикрепленных изображений и т.д.; целевая переменная — число просмотров
#
# * И любые другие ваши идеи, которые подходят под описанный выше формат

# %% [markdown]
# После сбора данных и объединения их в общий датасет, необходимо очистить его от мусора (в том числе, например, с помощью регулярных выражений); посчитать различные статистики по собранным данным (в случае если столбец текстовый, то, например, посчитать частотности слов, выявляя наиболее частотные слова, и т.д.); а также в целом провести EDA в контексте той бизнес-задачи, которую мы потенциально хотим решить по полученному датасету. В конце сделать выводы из проделанной работы.

# %% [markdown]
# ### Этапы проекта

# %% [markdown]
# Ниже для вашего удобства еще раз в краткой форме представляем примерные этапы реализации проекта:
#
# - Выбор источников данных, в соответствии с требованиями, описанными выше
# - Формулировка бизнес-задачи, которую могла бы хотеть решить компания/платформа, на основе собираемых данных
# - Обоснование сформулированной бизнес-задачи
# - Извлечение данных путём работы с API
# - Извлечение данных путём скрапинга и парсинга
# - Первичная обработка данных (EDA)
# - Получение и агрегация результатов, финальные выводы

# %% [markdown]
# ### Общие требования к проекту

# %% [markdown]
# В качестве результата выполнения группового проекта ваша команда должна получить презентацию, а также репозиторий с кодом на GitHub. Демонстрация репозитория и защита презентации перед комиссией осуществляется в фиксированную дату.
#
# Оформление презентации остаётся полностью на ваше усмотрение, но помните, что результат должен быть релевантен для демонстрации бизнес-заказчику — комиссию, принимающую вашу работу, правильнее всего воспринимать именно в таком качестве. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не рекомендуется.
#
# С точки зрения концепции выполнения проекта — вам необходимо принять на себя роль дата-инженеров: продумать идеологию получения и извлечения данных с платформы — и дата-аналитиков: соотнести бизнес-задачу с формулировками на языке данных и извлечь полезные инсайты из проделанной работы. А в конце, конечно, — презентовать всю эту красоту в понятном виде потенциальному заказчику.
#
# Разумеется, чем сложнее и чем нетривиальнее будет ваша задача, а также чем глубже и чем осмысленнее будут выводы, извлечённые в рамках этой задачи, — тем выше окажется качество вашего проекта и тем выше он будет оценён!

# %% [markdown]
# ### Полезные замечания и советы

# %% [markdown]
# - Графики и визуализации — это очень хорошо — все любят графики
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев
# - Не нужно делать просто текстовые слайды
# - Стройте свой проект, исходя из того, что ваша цель представить полезную информацию для бизнеса
# - Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами

# %% [markdown]
# ### Технические требования

# %% [markdown]
# Ниже чуть более детализированно будут представлены минимальные технические требования по всем основным этапам и составным частям выполняемого вами группового проекта.

# %% [markdown]
# #### Обязательный сбор данных через API

# %% [markdown]
# * Необходимо реализовать сбор данных через API для как минимум одного веб-сайта
# * При формировании датасета должно осуществляться **не менее 5** различных запросов к API
# * Данный этап является обязательным, что означает, что без его полного выполнения ***нельзя получить оценку за проект выше 1***

# %% [markdown]
# #### Обязательный сбор данных посредством скрапинга

# %% [markdown]
# * Необходимо реализовать сбор и парсинг данных через библиотеки `requests` / `bs4` и другие рассмотренные в рамках семинара для как минимум одного веб-сайта, отличного от веб-сайта из предыдущего пункта
# * Получившийся датасет должен содержать **не менее 10 000** записей
# * Данный этап является обязательным, что означает, что без его полного выполнения ***нельзя получить оценку за проект выше 1***

# %% [markdown]
# #### Разведочный анализ данных (EDA)

# %% [markdown]
# * Изучить особенности данных в рамках объединённого датасета:
#   * Есть ли пропущенные значения? Сколько? Какова их доля от общего числа объектов для каждого конкретного признака? И, в целом, насколько ваш датасет “разрежен” в контексте пропущенных значений? Выдвинуть и (желательно) проверить гипотезу, что могут означать пропущенные значения? Осмысленно и аргументированно обработать пропуски.
#   * Есть ли ошибочные  (например, отрицательный возраст или пятиметровый рост человека; 3-й класс в задаче бинарной классификации) значения (признаки, целевая переменная) в данных? Обработать их.
#   * Есть ли выбросы в данных? По возможности обработать их.
# * Изучить поведение каждого признака в отдельности, его связь с целевой переменной, а также попарные корреляции (в том числе и в особенности с таргетом). Визуализировать попарные распределения признаков и корреляции наиболее значимых.
# * Построить подходящие сводные таблицы и прочие диаграммы.
# * Если проведенный вами анализ позволяет сделать какие-либо выводы, постараться сформулировать их максимально глубоко и развернуто. Упомянуть, как можно задействовать в дальнейшем приобретенные вами на этом этапе знания в решаемой задаче.
# * Осуществить и другие осмысленные действия в рамках процесса EDA.

# %% [markdown]
# #### GitHub и требования при использовании СКВ

# %% [markdown]
# *   Для выполнения задания вы должны создать проект на GitHub (один репозиторий на всю команду!)
# *   Необходимо добавить в репозиторий `.gitignore` и не грузить в репозиторий лишние файлы
# *   Необходимо добавить в репозиторий `README.md` с подробным описанием проекта. В этот файл также необходимо добавить подробное описание данных — описание признаков, их тип, количество объектов каждого класса (в задачах классификации), информацию о пропущенных значениях (в т.ч о типичных филлерах, если это не `nan`). Также добавляйте другие релевантные вашей задачи описательные характеристики данных. После чтения этого файла у человека со стороны не должно остаться никаких вопросов про данные
# *   В репозитории проекта размещаются ноутбуки / скрипты со сбором данных
# *   Коммиты делаются осмысленно, с понятными внешнему наблюдателю комментариями — что было сделано по факту
# *   При разработке необходимо соблюдать [гитфлоу](https://www.umgum.com/gitlab-workflow)

# %% [markdown]
# #### Артефакты по окончании работы над проектом

# %% [markdown]
# * Ноутбуки / скрипты со сбором и извлечением данных
# * Ноутбуки c осуществлением EDA
# * Файл `.gitignore`
# * Заполненный файл `README.md` в репозитории проекта на гитхабе со ссылкой на данные и их подробным описанием, с выводами о проведенном EDA

# %% [markdown]
# #### Логирование

# %% [markdown]
# * Для получения высоких баллов добавьте в ваш проект логирование. Потренируйтесь включать и выключать его через файл настроек, а также задавать уровень логирования через этот же файл (не в приложении)
# * Запустите ваш код, чтобы сохранился файл с логами
# * Про логи можно почитать [тут](https://habr.com/ru/companies/wunderfund/articles/683880/) и [тут](https://tproger.ru/articles/shpargalka-po-logirovaniju-na-python)

# %% [markdown]
# #### Библиотека Selenium

# %% [markdown]
# * Для получения высоких баллов используйте библиотеку Selenium при сборе данных
# * Реализуйте имитацию работы пользователя через Selenium
# * Про данную библиотеку можно почитать [тут](https://habr.com/ru/companies/selectel/articles/754674/) и [тут](https://happypython.ru/2022/11/27/selenium-chromedriver-find-elements/)

# %% [markdown]
# ## Критерии оценки проекта

# %% [markdown]
# Оценка за групповой проект в целом — то есть первая из двух оценок — выставляется по 10 балльной шкале, исходя из 3 критериев. Также комиссия на своё усмотрение может добавить (но не снизить) некоторое количество бонусных баллов за рамками данных критериев.
#
# Каждый из критериев будет перечислен и рассмотрен ниже.

# %% [markdown]
# ### Критерий 1. Выбор задачи и EDA (до 3,5 баллов)
#
# Данный критерий оценивает, насколько обоснованной и осмысленной получилась решаемая бизнес-задача; насколько полно был осуществлен переход от бизнес-задачи к пайплайну подготовки данных (насколько в реальности формируемый датасет соответствует исходной постановке задачи с точки зрения интересов компании и насколько может помочь в решении такой задачи); а также насколько корректными, объёмными и прикладными для бизнеса получились выявленные в ходе исследования инсайты.

# %% [markdown]
# ### Критерий 2. GitHub (до 1 балла)
#
# Данный критерий оценивает, насколько корректным и квалифицированным было применение средств системы контроля версий в проекте; насколько были выполнены представленные в задании требования по всем необходимым файлам и условиям в рамках работы с GitHub; а также насколько эффективно данная система в действительности использовалась командой для распараллеливания задач по проекту.

# %% [markdown]
# ### Критерий 3. Инструменты извлечения данных (до 5,5 баллов)
#
# Данный критерий оценивает техническую реализацию процесса сбора данных автоматизированным образом с сайтов и порталов. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным.
#
# *__Важно:__ в случае оценки __1 балл и ниже__ за этот критерий — оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить __больше 1 балла__ только при условии применения как средств Data Scraping (автоматического считывания HTML-кода страниц с последующей его обработкой), так и средств API (получению данных с использованием официальных протоколов компании/портала). При этом средства Scraping и API следует применять к разным компаниям/порталам, но представленным в рамках одной и той же предметной области (бизнес-задачи).*
#
# *По данному критерию можно получить **3 балла и выше** только при условии использования в проекте логирования __ИЛИ__ библиотеки Selenium.*
#
# *По данному критерию можно получить **4 балла и выше** только при условии использования в проекте логирования __И__ библиотеки Selenium.*
#
# *По данному критерию можно получить **5 баллов и выше** только при условии использования в проекте логирования, библиотеки Selenium и, кроме этого, обоснованного применения дополнительных инструментов/подходов/библиотек, не упомянутых ранее в этом ноутбуке и не рассматривавшихся в рамках соответствующего семинара.*

# %%
# pip install selenium-wire
from seleniumwire import webdriver
from selenium.webdriver.common.by import By
import json
import time
import brotli
def parse_with_selenium_wire():
    # Создаём экземпляр браузера Selenium Wire (а не обычного webdriver)
    options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(seleniumwire_options={}, options=options)
    
    try:
        driver.get("https://realty.yandex.ru/offer/6298345976539630169/")
        
        # Делаем паузу или работаем дальше с сайтом, 
        # чтобы запросы успели отправиться и вернуться
        time.sleep(3)
        
        # Перебираем все запросы, которые прошли через браузер
        for req in driver.requests:
            # Ищем конкретные запросы, которые возвращают JSON с нужным вам endpoint
            if "map-nearby-suggestions" in req.url:
                body = req.response.body  # возвращает bytes
                decompressed = brotli.decompress(body)
                data_str = decompressed.decode('utf-8')
                data_json = json.loads(data_str)
                print(json.dumps(data_json, ensure_ascii=False, indent=4))
    finally:
        driver.quit()

if __name__ == "__main__":
    parse_with_selenium_wire()
# Out:
# {
#     "response": {
#         "points": [
#             {
#                 "id": "6298345976537928024",
#                 "item": {
#                     "fullImages": [
#                         "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14635834/9ba5f177-e729-412c-9ae7-eb17d6982d97/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14385517/8d7eb2bb-6ad2-43e6-bc4a-37f199b3a305/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15057490/5162647b-c1da-4854-a3e1-19c22168927c/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/82288ffc-ae08-4e78-9f5d-6761207ff8bc/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/652157aa-9546-46ed-9821-61745c0f1a63/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/4fcb0cad-05c7-4eef-af08-fcdc513cd07b/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14363166/8c6e817e-0cf6-45ac-8adb-24fbdae7b38c/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14770411/3370b844-ee7f-492a-801b-f09ee2a54485/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15074788/49729a81-12c4-491d-8bf2-96d32a08ed1f/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15209291/2f4c5f17-eaf8-416e-b768-80379094e425/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/0fb4e9ce-24ed-41da-963e-3fdd6f5bc383/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/bb32fc75-cea4-4a9e-b2db-5c041b12b3b1/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14814928/8f71da63-0f1c-46f4-9f0f-4803fcbd00bb/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14918062/aa97341e-e79e-4a11-a34f-8aa1f833488f/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/13945183/874c76bc-e584-4a87-a751-364057761d37/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/9896606/a33abd5d-eaa3-4c0d-8120-05db215e904d/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/fcd8cfe6-b967-482f-821f-6135beb6bdd9/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/11484904/06a55b01-b848-4807-a743-810bf03f51dc/large"
#                     ],
#                     "minicardImages": [
#                         "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14635834/9ba5f177-e729-412c-9ae7-eb17d6982d97/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14385517/8d7eb2bb-6ad2-43e6-bc4a-37f199b3a305/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15057490/5162647b-c1da-4854-a3e1-19c22168927c/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/82288ffc-ae08-4e78-9f5d-6761207ff8bc/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/652157aa-9546-46ed-9821-61745c0f1a63/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/4fcb0cad-05c7-4eef-af08-fcdc513cd07b/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14363166/8c6e817e-0cf6-45ac-8adb-24fbdae7b38c/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14770411/3370b844-ee7f-492a-801b-f09ee2a54485/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15074788/49729a81-12c4-491d-8bf2-96d32a08ed1f/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15209291/2f4c5f17-eaf8-416e-b768-80379094e425/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/0fb4e9ce-24ed-41da-963e-3fdd6f5bc383/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/bb32fc75-cea4-4a9e-b2db-5c041b12b3b1/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14814928/8f71da63-0f1c-46f4-9f0f-4803fcbd00bb/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14918062/aa97341e-e79e-4a11-a34f-8aa1f833488f/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13945183/874c76bc-e584-4a87-a751-364057761d37/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/9896606/a33abd5d-eaa3-4c0d-8120-05db215e904d/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/fcd8cfe6-b967-482f-821f-6135beb6bdd9/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/11484904/06a55b01-b848-4807-a743-810bf03f51dc/minicard"
#                     ],
#                     "appLargeImages": [
#                         "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14635834/9ba5f177-e729-412c-9ae7-eb17d6982d97/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14385517/8d7eb2bb-6ad2-43e6-bc4a-37f199b3a305/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15057490/5162647b-c1da-4854-a3e1-19c22168927c/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/82288ffc-ae08-4e78-9f5d-6761207ff8bc/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/652157aa-9546-46ed-9821-61745c0f1a63/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/4fcb0cad-05c7-4eef-af08-fcdc513cd07b/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14363166/8c6e817e-0cf6-45ac-8adb-24fbdae7b38c/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14770411/3370b844-ee7f-492a-801b-f09ee2a54485/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15074788/49729a81-12c4-491d-8bf2-96d32a08ed1f/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15209291/2f4c5f17-eaf8-416e-b768-80379094e425/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/0fb4e9ce-24ed-41da-963e-3fdd6f5bc383/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/bb32fc75-cea4-4a9e-b2db-5c041b12b3b1/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14814928/8f71da63-0f1c-46f4-9f0f-4803fcbd00bb/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14918062/aa97341e-e79e-4a11-a34f-8aa1f833488f/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/13945183/874c76bc-e584-4a87-a751-364057761d37/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/9896606/a33abd5d-eaa3-4c0d-8120-05db215e904d/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/fcd8cfe6-b967-482f-821f-6135beb6bdd9/app_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/11484904/06a55b01-b848-4807-a743-810bf03f51dc/app_large"
#                     ],
#                     "mainImages": [
#                         "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/14635834/9ba5f177-e729-412c-9ae7-eb17d6982d97/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/14385517/8d7eb2bb-6ad2-43e6-bc4a-37f199b3a305/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/15057490/5162647b-c1da-4854-a3e1-19c22168927c/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/82288ffc-ae08-4e78-9f5d-6761207ff8bc/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/652157aa-9546-46ed-9821-61745c0f1a63/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/4fcb0cad-05c7-4eef-af08-fcdc513cd07b/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/14363166/8c6e817e-0cf6-45ac-8adb-24fbdae7b38c/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/14770411/3370b844-ee7f-492a-801b-f09ee2a54485/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/15074788/49729a81-12c4-491d-8bf2-96d32a08ed1f/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/15209291/2f4c5f17-eaf8-416e-b768-80379094e425/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/0fb4e9ce-24ed-41da-963e-3fdd6f5bc383/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/bb32fc75-cea4-4a9e-b2db-5c041b12b3b1/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/14814928/8f71da63-0f1c-46f4-9f0f-4803fcbd00bb/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/14918062/aa97341e-e79e-4a11-a34f-8aa1f833488f/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/13945183/874c76bc-e584-4a87-a751-364057761d37/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/9896606/a33abd5d-eaa3-4c0d-8120-05db215e904d/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/fcd8cfe6-b967-482f-821f-6135beb6bdd9/main",
#                         "//avatars.mds.yandex.net/get-realty-offers/11484904/06a55b01-b848-4807-a743-810bf03f51dc/main"
#                     ],
#                     "appMiddleImages": [
#                         "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14635834/9ba5f177-e729-412c-9ae7-eb17d6982d97/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14385517/8d7eb2bb-6ad2-43e6-bc4a-37f199b3a305/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15057490/5162647b-c1da-4854-a3e1-19c22168927c/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/82288ffc-ae08-4e78-9f5d-6761207ff8bc/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/652157aa-9546-46ed-9821-61745c0f1a63/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/4fcb0cad-05c7-4eef-af08-fcdc513cd07b/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14363166/8c6e817e-0cf6-45ac-8adb-24fbdae7b38c/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14770411/3370b844-ee7f-492a-801b-f09ee2a54485/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15074788/49729a81-12c4-491d-8bf2-96d32a08ed1f/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15209291/2f4c5f17-eaf8-416e-b768-80379094e425/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/0fb4e9ce-24ed-41da-963e-3fdd6f5bc383/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/bb32fc75-cea4-4a9e-b2db-5c041b12b3b1/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14814928/8f71da63-0f1c-46f4-9f0f-4803fcbd00bb/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14918062/aa97341e-e79e-4a11-a34f-8aa1f833488f/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/13945183/874c76bc-e584-4a87-a751-364057761d37/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/9896606/a33abd5d-eaa3-4c0d-8120-05db215e904d/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/fcd8cfe6-b967-482f-821f-6135beb6bdd9/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/11484904/06a55b01-b848-4807-a743-810bf03f51dc/app_middle"
#                     ],
#                     "appMiddleSnippetImages": [
#                         "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14635834/9ba5f177-e729-412c-9ae7-eb17d6982d97/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14385517/8d7eb2bb-6ad2-43e6-bc4a-37f199b3a305/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15057490/5162647b-c1da-4854-a3e1-19c22168927c/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/82288ffc-ae08-4e78-9f5d-6761207ff8bc/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/652157aa-9546-46ed-9821-61745c0f1a63/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/4fcb0cad-05c7-4eef-af08-fcdc513cd07b/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14363166/8c6e817e-0cf6-45ac-8adb-24fbdae7b38c/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14770411/3370b844-ee7f-492a-801b-f09ee2a54485/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15074788/49729a81-12c4-491d-8bf2-96d32a08ed1f/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15209291/2f4c5f17-eaf8-416e-b768-80379094e425/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/0fb4e9ce-24ed-41da-963e-3fdd6f5bc383/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/bb32fc75-cea4-4a9e-b2db-5c041b12b3b1/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14814928/8f71da63-0f1c-46f4-9f0f-4803fcbd00bb/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14918062/aa97341e-e79e-4a11-a34f-8aa1f833488f/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/13945183/874c76bc-e584-4a87-a751-364057761d37/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/9896606/a33abd5d-eaa3-4c0d-8120-05db215e904d/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/fcd8cfe6-b967-482f-821f-6135beb6bdd9/app_middle",
#                         "//avatars.mds.yandex.net/get-realty-offers/11484904/06a55b01-b848-4807-a743-810bf03f51dc/app_middle"
#                     ],
#                     "appLargeSnippetImages": [
#                         "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14635834/9ba5f177-e729-412c-9ae7-eb17d6982d97/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14385517/8d7eb2bb-6ad2-43e6-bc4a-37f199b3a305/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15057490/5162647b-c1da-4854-a3e1-19c22168927c/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/82288ffc-ae08-4e78-9f5d-6761207ff8bc/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/652157aa-9546-46ed-9821-61745c0f1a63/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/4fcb0cad-05c7-4eef-af08-fcdc513cd07b/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14363166/8c6e817e-0cf6-45ac-8adb-24fbdae7b38c/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14770411/3370b844-ee7f-492a-801b-f09ee2a54485/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15074788/49729a81-12c4-491d-8bf2-96d32a08ed1f/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15209291/2f4c5f17-eaf8-416e-b768-80379094e425/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/0fb4e9ce-24ed-41da-963e-3fdd6f5bc383/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/bb32fc75-cea4-4a9e-b2db-5c041b12b3b1/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14814928/8f71da63-0f1c-46f4-9f0f-4803fcbd00bb/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14918062/aa97341e-e79e-4a11-a34f-8aa1f833488f/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/13945183/874c76bc-e584-4a87-a751-364057761d37/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/9896606/a33abd5d-eaa3-4c0d-8120-05db215e904d/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/fcd8cfe6-b967-482f-821f-6135beb6bdd9/app_snippet_large",
#                         "//avatars.mds.yandex.net/get-realty-offers/11484904/06a55b01-b848-4807-a743-810bf03f51dc/app_snippet_large"
#                     ],
#                     "active": true,
#                     "area": {
#                         "value": 98.4,
#                         "unit": "SQUARE_METER"
#                     },
#                     "building": {
#                         "builtYear": 2028,
#                         "builtQuarter": 1,
#                         "buildingState": "UNFINISHED",
#                         "buildingType": "MONOLIT",
#                         "improvements": {
#                             "PARKING": true,
#                             "LIFT": true,
#                             "SECURITY": false
#                         },
#                         "parkingType": "OPEN",
#                         "siteId": 3969324,
#                         "siteName": "Монблан",
#                         "siteDisplayName": "Элитный жилой комплекс «Монблан»",
#                         "developerIds": [
#                             270044
#                         ],
#                         "houseId": "4097602",
#                         "houseReadableName": "Секция 3",
#                         "heatingType": "UNKNOWN",
#                         "locativeFullName": "в элитном жилом комплексе «Монблан»",
#                         "hasDeveloperChat": false,
#                         "apartmentType": "FLATS",
#                         "buildingImprovementsMap": {
#                             "PARKING": true,
#                             "LIFT": true,
#                             "SECURITY": false
#                         }
#                     },
#                     "creationDate": "2024-12-12T23:54:02Z",
#                     "dealStatus": "PRIMARY_SALE",
#                     "flatType": "NEW_FLAT",
#                     "floorsOffered": [
#                         2
#                     ],
#                     "floorsTotal": 7,
#                     "house": {
#                         "bathroomUnit": "TWO_AND_MORE",
#                         "balconyType": "LOGGIA",
#                         "windowView": "YARD",
#                         "apartments": false,
#                         "housePart": false
#                     },
#                     "livingSpace": {
#                         "value": 64.5,
#                         "unit": "SQUARE_METER"
#                     },
#                     "location": {
#                         "rgid": 193301,
#                         "geoId": 213,
#                         "populatedRgid": 587795,
#                         "subjectFederationId": 1,
#                         "subjectFederationRgid": 741964,
#                         "settlementRgid": 587795,
#                         "settlementGeoId": 213,
#                         "address": "Москва, Шлюзовая набережная",
#                         "geocoderAddress": "Россия, Москва, Шлюзовая набережная, 2/1с1",
#                         "structuredAddress": {
#                             "component": [
#                                 {
#                                     "value": "Россия",
#                                     "geoId": 225,
#                                     "regionGraphId": "143",
#                                     "address": "Россия",
#                                     "regionType": "COUNTRY",
#                                     "queryParams": {
#                                         "rgid": "143",
#                                         "address": "Россия"
#                                     },
#                                     "populatedRgid": "143"
#                                 },
#                                 {
#                                     "value": "Москва",
#                                     "geoId": 213,
#                                     "regionGraphId": "587795",
#                                     "address": "Москва",
#                                     "regionType": "CITY",
#                                     "queryParams": {
#                                         "rgid": "587795",
#                                         "address": "Россия, Москва"
#                                     },
#                                     "populatedRgid": "587795"
#                                 },
#                                 {
#                                     "value": "Шлюзовая набережная",
#                                     "geoId": 213,
#                                     "regionGraphId": "587795",
#                                     "address": "Шлюзовая набережная",
#                                     "regionType": "STREET",
#                                     "queryParams": {
#                                         "rgid": "587795",
#                                         "address": "Россия, Москва, Шлюзовая набережная"
#                                     },
#                                     "populatedRgid": "587795"
#                                 }
#                             ]
#                         },
#                         "point": {
#                             "latitude": 55.73247,
#                             "longitude": 37.642536,
#                             "precision": "EXACT"
#                         },
#                         "metro": {
#                             "metroGeoId": 20475,
#                             "metroCityRgid": 587795,
#                             "name": "Павелецкая",
#                             "metroTransport": "ON_FOOT",
#                             "timeToMetro": 6,
#                             "latitude": 55.73001,
#                             "longitude": 37.638412,
#                             "minTimeToMetro": 6,
#                             "lineColors": [
#                                 "74BE4B",
#                                 "4f8242",
#                                 "794835"
#                             ],
#                             "rgbColor": "74BE4B"
#                         },
#                         "station": {
#                             "name": "Москва (Павелецкий вокзал)",
#                             "distanceKm": 0.348
#                         },
#                         "streetAddress": "Шлюзовая набережная, 2/1с1",
#                         "metroList": [
#                             {
#                                 "metroGeoId": 20475,
#                                 "metroCityRgid": 587795,
#                                 "name": "Павелецкая",
#                                 "metroTransport": "ON_FOOT",
#                                 "timeToMetro": 6,
#                                 "latitude": 55.73001,
#                                 "longitude": 37.638412,
#                                 "minTimeToMetro": 6,
#                                 "lineColors": [
#                                     "74BE4B",
#                                     "4f8242",
#                                     "794835"
#                                 ],
#                                 "rgbColor": "74BE4B"
#                             },
#                             {
#                                 "metroGeoId": 20474,
#                                 "metroCityRgid": 587795,
#                                 "name": "Новокузнецкая",
#                                 "metroTransport": "ON_TRANSPORT",
#                                 "timeToMetro": 8,
#                                 "latitude": 55.74237,
#                                 "longitude": 37.629242,
#                                 "minTimeToMetro": 8,
#                                 "lineColors": [
#                                     "4f8242"
#                                 ],
#                                 "rgbColor": "4f8242"
#                             }
#                         ],
#                         "parks": [
#                             {
#                                 "parkId": "4365335396",
#                                 "name": "ландшафтный парк на Павелецкой площади",
#                                 "timeOnFoot": 291,
#                                 "distanceOnFoot": 405,
#                                 "latitude": 55.731552,
#                                 "longitude": 37.64018,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_FOOT",
#                                         "time": 4,
#                                         "distance": 405
#                                     }
#                                 ],
#                                 "parkType": "PARK"
#                             },
#                             {
#                                 "parkId": "121373426",
#                                 "name": "Михайловский сад",
#                                 "timeOnFoot": 452,
#                                 "distanceOnFoot": 628,
#                                 "latitude": 55.734543,
#                                 "longitude": 37.637867,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_FOOT",
#                                         "time": 7,
#                                         "distance": 628
#                                     }
#                                 ],
#                                 "parkType": "PARK"
#                             }
#                         ],
#                         "ponds": [
#                             {
#                                 "pondId": "137617928",
#                                 "name": "Водоотводный канал",
#                                 "timeOnFoot": 132,
#                                 "distanceOnFoot": 184,
#                                 "latitude": 55.73284,
#                                 "longitude": 37.642845,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_FOOT",
#                                         "time": 2,
#                                         "distance": 184
#                                     }
#                                 ],
#                                 "pondType": "CANAL"
#                             },
#                             {
#                                 "pondId": "164138924",
#                                 "name": "Новоспасский пруд",
#                                 "timeOnFoot": 420,
#                                 "distanceOnFoot": 651,
#                                 "latitude": 55.732296,
#                                 "longitude": 37.652874,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_FOOT",
#                                         "time": 7,
#                                         "distance": 651
#                                     }
#                                 ],
#                                 "pondType": "POND"
#                             },
#                             {
#                                 "pondId": "137667589",
#                                 "name": "река Москва",
#                                 "timeOnFoot": 551,
#                                 "distanceOnFoot": 766,
#                                 "latitude": 55.734993,
#                                 "longitude": 37.647877,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_FOOT",
#                                         "time": 9,
#                                         "distance": 766
#                                     }
#                                 ],
#                                 "pondType": "RIVER"
#                             }
#                         ],
#                         "airports": [
#                             {
#                                 "id": "878042",
#                                 "name": "Шереметьево",
#                                 "timeOnCar": 2101,
#                                 "distanceOnCar": 35006,
#                                 "latitude": 55.963852,
#                                 "longitude": 37.4169,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_CAR",
#                                         "time": 35,
#                                         "distance": 35006
#                                     }
#                                 ]
#                             },
#                             {
#                                 "id": "858742",
#                                 "name": "Домодедово",
#                                 "timeOnCar": 2782,
#                                 "distanceOnCar": 42294,
#                                 "latitude": 55.41435,
#                                 "longitude": 37.90048,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_CAR",
#                                         "time": 46,
#                                         "distance": 42294
#                                     }
#                                 ]
#                             },
#                             {
#                                 "id": "878065",
#                                 "name": "Внуково",
#                                 "timeOnCar": 2900,
#                                 "distanceOnCar": 32051,
#                                 "latitude": 55.604942,
#                                 "longitude": 37.282578,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_CAR",
#                                         "time": 48,
#                                         "distance": 32051
#                                     }
#                                 ]
#                             },
#                             {
#                                 "id": "878109",
#                                 "name": "Жуковский (Раменское)",
#                                 "timeOnCar": 3060,
#                                 "distanceOnCar": 42700,
#                                 "latitude": 55.568665,
#                                 "longitude": 38.143654,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_CAR",
#                                         "time": 51,
#                                         "distance": 42700
#                                     }
#                                 ]
#                             }
#                         ],
#                         "heatmaps": [
#                             {
#                                 "name": "infrastructure",
#                                 "rgbColor": "20a70a",
#                                 "description": "отличная",
#                                 "level": 7,
#                                 "maxLevel": 8,
#                                 "title": "Инфраструктура"
#                             },
#                             {
#                                 "name": "transport",
#                                 "rgbColor": "30ce12",
#                                 "description": "высокая",
#                                 "level": 7,
#                                 "maxLevel": 9,
#                                 "title": "Общественный транспорт"
#                             }
#                         ],
#                         "allHeatmaps": [
#                             {
#                                 "name": "infrastructure",
#                                 "rgbColor": "20a70a",
#                                 "description": "отличная",
#                                 "level": 7,
#                                 "maxLevel": 8,
#                                 "title": "Инфраструктура"
#                             },
#                             {
#                                 "name": "price-rent",
#                                 "rgbColor": "fbae1e",
#                                 "description": "высокая",
#                                 "level": 4,
#                                 "maxLevel": 9,
#                                 "title": "Цена аренды"
#                             },
#                             {
#                                 "name": "price-sell",
#                                 "rgbColor": "ee4613",
#                                 "description": "очень высокая",
#                                 "level": 2,
#                                 "maxLevel": 9,
#                                 "title": "Цена продажи"
#                             },
#                             {
#                                 "name": "profitability",
#                                 "rgbColor": "ffe424",
#                                 "description": "средняя",
#                                 "level": 5,
#                                 "maxLevel": 9,
#                                 "title": "Прогноз окупаемости"
#                             },
#                             {
#                                 "name": "transport",
#                                 "rgbColor": "30ce12",
#                                 "description": "высокая",
#                                 "level": 7,
#                                 "maxLevel": 9,
#                                 "title": "Общественный транспорт"
#                             },
#                             {
#                                 "name": "carsharing",
#                                 "rgbColor": "30ce12",
#                                 "description": "высокая",
#                                 "level": 6,
#                                 "maxLevel": 8,
#                                 "title": "Доступность Яндекс.Драйва"
#                             }
#                         ],
#                         "subjectFederationName": "Москва и МО",
#                         "streetId": 151963,
#                         "cityCenter": [
#                             {
#                                 "transport": "ON_CAR",
#                                 "time": 337,
#                                 "distance": 3908,
#                                 "latitude": 55.749893,
#                                 "longitude": 37.623425,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_CAR",
#                                         "time": 5,
#                                         "distance": 3908
#                                     }
#                                 ]
#                             }
#                         ]
#                     },
#                     "newBuilding": true,
#                     "obsolete": false,
#                     "offerId": "6298345976537928024",
#                     "offerCategory": "APARTMENT",
#                     "offerType": "SELL",
#                     "openPlan": false,
#                     "partnerId": "1069346146",
#                     "photoPreviews": [
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "..."
#                     ],
#                     "premium": false,
#                     "price": {
#                         "currency": "RUR",
#                         "value": 113850400,
#                         "period": "WHOLE_LIFE",
#                         "unit": "WHOLE_OFFER",
#                         "trend": "INCREASED",
#                         "previous": 101255200,
#                         "hasPriceHistory": true,
#                         "valuePerPart": 1157016,
#                         "unitPerPart": "SQUARE_METER",
#                         "valueForWhole": 113850400,
#                         "unitForWhole": "WHOLE_OFFER",
#                         "price": {
#                             "value": 113850400,
#                             "currency": "RUB",
#                             "priceType": "PER_OFFER",
#                             "pricingPeriod": "WHOLE_LIFE"
#                         },
#                         "pricePerPart": {
#                             "value": 1157016,
#                             "currency": "RUB",
#                             "priceType": "PER_METER",
#                             "pricingPeriod": "WHOLE_LIFE"
#                         },
#                         "priceForWhole": {
#                             "value": 113850400,
#                             "currency": "RUB",
#                             "priceType": "PER_OFFER",
#                             "pricingPeriod": "WHOLE_LIFE"
#                         }
#                     },
#                     "primarySaleV2": true,
#                     "promoted": true,
#                     "raised": false,
#                     "remoteReview": {
#                         "onlineShow": false,
#                         "youtubeVideoReviewUrl": "https://youtu.be/KzdakzEeWcQ"
#                     },
#                     "roomsTotal": 2,
#                     "salesDepartments": [
#                         {
#                             "id": 2435366,
#                             "name": "Галс-Девелопмент",
#                             "isRedirectPhones": true,
#                             "weekTimetable": [
#                                 {
#                                     "dayFrom": 1,
#                                     "dayTo": 5,
#                                     "timePattern": [
#                                         {
#                                             "open": "09:00",
#                                             "close": "21:00"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "dayFrom": 6,
#                                     "dayTo": 7,
#                                     "timePattern": [
#                                         {
#                                             "open": "10:00",
#                                             "close": "20:00"
#                                         }
#                                     ]
#                                 }
#                             ],
#                             "logo": "//avatars.mds.yandex.net/get-realty-content/8111885/4ec0edd7-4349-4467-a603-2e2b34c78a9f/builder_logo_info",
#                             "timetableZoneMinutes": 180,
#                             "hasCallback": false,
#                             "campaignId": "f57b61c0-49fa-4790-b37d-3ed3fcc5aa9b",
#                             "hasSip": true,
#                             "hasProCard": true,
#                             "sip": [
#                                 "sip:74954895686@trunk.uiscom.ru:9090"
#                             ],
#                             "companyType": 3,
#                             "statParams": "...",
#                             "encryptedPhones": [
#                                 "KzcF5NHjcJwNLTgNwNPDcR3"
#                             ],
#                             "encryptedDump": "..."
#                         }
#                     ],
#                     "suspicious": false,
#                     "totalImages": 19,
#                     "transactionConditionsMap": {
#                         "MORTGAGE": true
#                     },
#                     "uid": "138633887",
#                     "updateDate": "2025-03-03T15:54:17Z",
#                     "vas": {
#                         "raised": false,
#                         "premium": false,
#                         "placement": false,
#                         "promoted": true,
#                         "turboSale": false,
#                         "raisingSale": false,
#                         "tuzFeatured": false,
#                         "vasAvailable": true
#                     },
#                     "yandexRent": false,
#                     "yandexProdaja": false,
#                     "shareUrl": "https://realty.yandex.ru/offer/6298345976537928024",
#                     "author": {
#                         "id": "0",
#                         "category": "DEVELOPER",
#                         "organization": "ГК «Галс-Девелопмент»",
#                         "agentName": "Недвижимость от застройщика",
#                         "creationDate": "2019-02-28T12:57:14Z",
#                         "humanPhoto": "//avatars.mds.yandex.net/get-yapic/35885/o6n8TND9stya4xCdaxSstznEM-1/islands-200",
#                         "allowedCommunicationChannels": [
#                             "COM_CALLS"
#                         ],
#                         "redirectPhones": true,
#                         "redirectPhonesFailed": false,
#                         "name": "ГК «Галс-Девелопмент»",
#                         "encryptedPhones": [
#                             "KzcF5NHjcJwNLTgNwNPDcR3"
#                         ]
#                     },
#                     "extImages": {
#                         "IMAGE_PLAN": {
#                             "fullImages": [
#                                 "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/large"
#                             ],
#                             "minicardImages": [
#                                 "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/minicard"
#                             ],
#                             "appLargeImages": [
#                                 "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/app_large"
#                             ],
#                             "mainImages": [
#                                 "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/main"
#                             ],
#                             "appMiddleImages": [
#                                 "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/app_middle"
#                             ],
#                             "appMiddleSnippetImages": [
#                                 "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/app_snippet_middle"
#                             ],
#                             "appLargeSnippetImages": [
#                                 "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/app_snippet_large"
#                             ],
#                             "totalImages": 1
#                         }
#                     },
#                     "withBilling": true,
#                     "appMiniSnippetImages": [
#                         "//avatars.mds.yandex.net/get-realty-offers/13732998/f7bb14b7-1b97-4133-a717-bffe703ee469/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14635834/9ba5f177-e729-412c-9ae7-eb17d6982d97/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14385517/8d7eb2bb-6ad2-43e6-bc4a-37f199b3a305/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15057490/5162647b-c1da-4854-a3e1-19c22168927c/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/82288ffc-ae08-4e78-9f5d-6761207ff8bc/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/652157aa-9546-46ed-9821-61745c0f1a63/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/4fcb0cad-05c7-4eef-af08-fcdc513cd07b/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14363166/8c6e817e-0cf6-45ac-8adb-24fbdae7b38c/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14770411/3370b844-ee7f-492a-801b-f09ee2a54485/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15074788/49729a81-12c4-491d-8bf2-96d32a08ed1f/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15209291/2f4c5f17-eaf8-416e-b768-80379094e425/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/0fb4e9ce-24ed-41da-963e-3fdd6f5bc383/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/15106371/bb32fc75-cea4-4a9e-b2db-5c041b12b3b1/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14814928/8f71da63-0f1c-46f4-9f0f-4803fcbd00bb/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14918062/aa97341e-e79e-4a11-a34f-8aa1f833488f/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13945183/874c76bc-e584-4a87-a751-364057761d37/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/9896606/a33abd5d-eaa3-4c0d-8120-05db215e904d/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/fcd8cfe6-b967-482f-821f-6135beb6bdd9/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/11484904/06a55b01-b848-4807-a743-810bf03f51dc/minicard"
#                     ]
#                 },
#                 "lat": 55.73247,
#                 "lon": 37.642536,
#                 "price": 113850400
#             },
#             {
#                 "id": "6298345976537928026",
#                 "item": {
#                     "fullImages": [
#                         "//avatars.mds.yandex.net/get-realty-offers/15239606/4d59b43e-3be3-405a-b9ba-56f31d887b6e/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/13745081/8ffc300f-0818-418c-9bd0-8947024bc2d5/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14385517/8d7eb2bb-6ad2-43e6-bc4a-37f199b3a305/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15057490/5162647b-c1da-4854-a3e1-19c22168927c/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/82288ffc-ae08-4e78-9f5d-6761207ff8bc/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/15037245/652157aa-9546-46ed-9821-61745c0f1a63/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14824781/4fcb0cad-05c7-4eef-af08-fcdc513cd07b/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14363166/8c6e817e-0cf6-45ac-8adb-24fbdae7b38c/large",
#                         "//avatars.mds.yandex.net/get-realty-offers/14770411/3370b844-ee7f-492a-801b-f09ee2a54485/large",
# ...
#                                     {
#                                         "transport": "ON_CAR",
#                                         "time": 37,
#                                         "distance": 36540
#                                     }
#                                 ]
#                             },
#                             {
#                                 "id": "858742",
#                                 "name": "Домодедово",
#                                 "timeOnCar": 2810,
#                                 "distanceOnCar": 42090,
#                                 "latitude": 55.41435,
#                                 "longitude": 37.90048,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_CAR",
#                                         "time": 46,
#                                         "distance": 42090
#                                     }
#                                 ]
#                             },
#                             {
#                                 "id": "878065",
#                                 "name": "Внуково",
#                                 "timeOnCar": 2889,
#                                 "distanceOnCar": 31389,
#                                 "latitude": 55.604942,
#                                 "longitude": 37.282578,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_CAR",
#                                         "time": 48,
#                                         "distance": 31389
#                                     }
#                                 ]
#                             },
#                             {
#                                 "id": "878109",
#                                 "name": "Жуковский (Раменское)",
#                                 "timeOnCar": 3163,
#                                 "distanceOnCar": 44586,
#                                 "latitude": 55.568665,
#                                 "longitude": 38.143654,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_CAR",
#                                         "time": 52,
#                                         "distance": 44586
#                                     }
#                                 ]
#                             }
#                         ],
#                         "heatmaps": [
#                             {
#                                 "name": "infrastructure",
#                                 "rgbColor": "128000",
#                                 "description": "отличная",
#                                 "level": 8,
#                                 "maxLevel": 8,
#                                 "title": "Инфраструктура"
#                             },
#                             {
#                                 "name": "transport",
#                                 "rgbColor": "30ce12",
#                                 "description": "высокая",
#                                 "level": 7,
#                                 "maxLevel": 9,
#                                 "title": "Общественный транспорт"
#                             }
#                         ],
#                         "allHeatmaps": [
#                             {
#                                 "name": "infrastructure",
#                                 "rgbColor": "128000",
#                                 "description": "отличная",
#                                 "level": 8,
#                                 "maxLevel": 8,
#                                 "title": "Инфраструктура"
#                             },
#                             {
#                                 "name": "price-rent",
#                                 "rgbColor": "fbae1e",
#                                 "description": "высокая",
#                                 "level": 4,
#                                 "maxLevel": 9,
#                                 "title": "Цена аренды"
#                             },
#                             {
#                                 "name": "price-sell",
#                                 "rgbColor": "f87c19",
#                                 "description": "высокая",
#                                 "level": 3,
#                                 "maxLevel": 9,
#                                 "title": "Цена продажи"
#                             },
#                             {
#                                 "name": "profitability",
#                                 "rgbColor": "9ada1b",
#                                 "description": "выше средней",
#                                 "level": 6,
#                                 "maxLevel": 9,
#                                 "title": "Прогноз окупаемости"
#                             },
#                             {
#                                 "name": "transport",
#                                 "rgbColor": "30ce12",
#                                 "description": "высокая",
#                                 "level": 7,
#                                 "maxLevel": 9,
#                                 "title": "Общественный транспорт"
#                             },
#                             {
#                                 "name": "carsharing",
#                                 "rgbColor": "30ce12",
#                                 "description": "высокая",
#                                 "level": 6,
#                                 "maxLevel": 8,
#                                 "title": "Доступность Яндекс.Драйва"
#                             }
#                         ],
#                         "subjectFederationName": "Москва и МО",
#                         "buildingId": "3817538966626111180",
#                         "streetId": 35015,
#                         "cityCenter": [
#                             {
#                                 "transport": "ON_CAR",
#                                 "time": 481,
#                                 "distance": 4083,
#                                 "latitude": 55.749893,
#                                 "longitude": 37.623425,
#                                 "timeDistanceList": [
#                                     {
#                                         "transport": "ON_CAR",
#                                         "time": 8,
#                                         "distance": 4083
#                                     }
#                                 ]
#                             }
#                         ]
#                     },
#                     "newBuilding": false,
#                     "obsolete": false,
#                     "offerId": "4870105568005761205",
#                     "offerCategory": "APARTMENT",
#                     "offerType": "SELL",
#                     "openPlan": false,
#                     "partnerId": "1069239354",
#                     "photoPreviews": [
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "...",
#                         "..."
#                     ],
#                     "predictions": {
#                         "predictedPrice": {
#                             "min": "29879000",
#                             "max": "36519000",
#                             "value": "33199000"
#                         }
#                     },
#                     "premium": false,
#                     "price": {
#                         "currency": "RUR",
#                         "value": 41017440,
#                         "period": "WHOLE_LIFE",
#                         "unit": "WHOLE_OFFER",
#                         "trend": "INCREASED",
#                         "previous": 40651568,
#                         "hasPriceHistory": true,
#                         "valuePerPart": 589331,
#                         "unitPerPart": "SQUARE_METER",
#                         "valueForWhole": 41017440,
#                         "unitForWhole": "WHOLE_OFFER",
#                         "price": {
#                             "value": 41017440,
#                             "currency": "RUB",
#                             "priceType": "PER_OFFER",
#                             "pricingPeriod": "WHOLE_LIFE"
#                         },
#                         "pricePerPart": {
#                             "value": 589331,
#                             "currency": "RUB",
#                             "priceType": "PER_METER",
#                             "pricingPeriod": "WHOLE_LIFE"
#                         },
#                         "priceForWhole": {
#                             "value": 41017440,
#                             "currency": "RUB",
#                             "priceType": "PER_OFFER",
#                             "pricingPeriod": "WHOLE_LIFE"
#                         }
#                     },
#                     "primarySaleV2": true,
#                     "promoted": false,
#                     "raised": false,
#                     "remoteReview": {
#                         "onlineShow": false,
#                         "youtubeVideoReviewUrl": ""
#                     },
#                     "roomsTotal": 2,
#                     "salesDepartments": [
#                         {
#                             "id": 2078590,
#                             "name": "Группа «Самолет»",
#                             "isRedirectPhones": true,
#                             "weekTimetable": [
#                                 {
#                                     "dayFrom": 1,
#                                     "dayTo": 7,
#                                     "timePattern": [
#                                         {
#                                             "open": "09:00",
#                                             "close": "21:00"
#                                         }
#                                     ]
#                                 }
#                             ],
#                             "logo": "//avatars.mds.yandex.net/get-realty-content/8111885/03f83571-fd69-4b6c-b656-a3f84899beae/builder_logo_info",
#                             "timetableZoneMinutes": 180,
#                             "hasCallback": true,
#                             "campaignId": "eaab54bf-561f-4c13-a5cf-803537816240",
#                             "hasSip": true,
#                             "sip": [
#                                 "sip:74958449051@sip100.sip-gate.telemir.net"
#                             ],
#                             "companyType": 3,
#                             "statParams": "...",
#                             "encryptedPhones": [
#                                 "KzcF5NHjUJxNLjkNzNPzURz"
#                             ],
#                             "encryptedDump": "..."
#                         }
#                     ],
#                     "suspicious": false,
#                     "totalImages": 20,
#                     "transactionConditionsMap": {
#                         "MORTGAGE": true
#                     },
#                     "uid": "561248415",
#                     "updateDate": "2025-02-26T16:10:24Z",
#                     "vas": {
#                         "raised": false,
#                         "premium": false,
#                         "placement": false,
#                         "promoted": false,
#                         "turboSale": false,
#                         "raisingSale": false,
#                         "tuzFeatured": false,
#                         "vasAvailable": true
#                     },
#                     "yandexRent": false,
#                     "yandexProdaja": false,
#                     "shareUrl": "https://realty.yandex.ru/offer/4870105568005761205",
#                     "author": {
#                         "id": "0",
#                         "category": "DEVELOPER",
#                         "organization": "Группа «Самолет»",
#                         "agentName": "Группа «Самолет»",
#                         "partnerSaleAgentId": "132",
#                         "creationDate": "2019-06-07T14:59:08Z",
#                         "humanPhoto": "//avatars.mds.yandex.net/get-yapic/15430/0b-7/islands-200",
#                         "allowedCommunicationChannels": [
#                             "COM_CALLS"
#                         ],
#                         "redirectPhones": true,
#                         "redirectPhonesFailed": false,
#                         "name": "Группа «Самолет»",
#                         "encryptedPhones": [
#                             "KzcF5NHjUJxNLjkNzNPzURz"
#                         ]
#                     },
#                     "backCallTrafficInfo": {
#                         "campaign": "offerid=4870105568005761205__siteid=2003613__partnerid=1069239354",
#                         "source": "touch.realty.serp.offer"
#                     },
#                     "withBilling": true,
#                     "appMiniSnippetImages": [
#                         "//avatars.mds.yandex.net/get-realty-offers/10246351/7b923617-3d00-4931-a968-2737d20c9e8d/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13813756/8b20495b-dd2e-4bb2-b2b7-fcafdd771ec9/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13971415/f5d31a04-6a1d-40ab-88d0-c2f35aa9e55f/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13920606/b69c8103-6159-465a-8c14-e54e4d42b4b3/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13971415/fe4de4ba-cda9-419b-89b9-55cc2aa76e6a/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13971415/bf13d9b5-7f7e-4619-a50b-ecc25b0322ed/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13853239/631bc966-4210-4f1b-a664-f9c7721353bf/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13813756/807e6c3d-f7a7-48c9-8cdb-66e741ef48e8/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14098308/bbec26c7-7eb6-44ae-aa45-d4189b55830e/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13971415/e31b46dd-c3d5-4ef1-86be-d8660bb3ec5b/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13853239/a9d0df6b-f2da-4d8f-b788-c0483038647f/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13853239/c0903d24-3024-4b7e-9d42-b804e93b50f5/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13920606/e29cb77d-c817-443b-a4c7-8202c8e08251/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14106973/65d2a63d-00f5-4abb-930f-984c8998f396/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13813756/9e50cb60-f25a-4588-9b22-ef4701738ffe/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14106973/0b1c69d8-f227-4087-b991-545b636551d2/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/14106973/f9bc42fe-b405-4b03-84c2-c93aed25b6dc/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13580435/2a019da2-8de1-4f1d-8c56-32dc2484bf5e/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13813756/05019609-2b1f-45c5-82a0-0f9fd1a7ec9b/minicard",
#                         "//avatars.mds.yandex.net/get-realty-offers/13971415/4abe205d-74d1-48cb-99ba-1faad81d7330/minicard"
#                     ]
#                 },
#                 "lat": 55.72898,
#                 "lon": 37.636276,
#                 "price": 41017440
#             }
#         ]
#     }
# }

# %%
import time
import brotli
import json
from seleniumwire import webdriver
from selenium.webdriver.common.by import By

def scrape_yandex_realty_unified():
    """
    1) Ходит по страницам, добавляя ?page=N к URL.
    2) Находит карточки (по data-test="IndexPageSnippetsSnippetOffer").
    3) Кликает по каждой карточке (открывается новая вкладка).
    4) Переключается в новую вкладку, ждёт сетевые запросы, ищет "map-nearby-suggestions",
       декомпрессирует (brotli), парсит JSON, проверяет имя застройщика в списке.
    5) Закрывает вкладку, возвращается к вкладке со списком.
    6) Идёт на следующую страницу, пока не достигнет max_pages или карточки не закончатся.
    """

    ops = webdriver.ChromeOptions()
    # При желании можно запустить без интерфейса:
    # ops.add_argument("--headless")
    drv = webdriver.Chrome(seleniumwire_options={}, options=ops)

    try:
        # Базовый URL без page=... (оно будет добавляться через ?page=N)
        base_url = "https://realty.yandex.ru/moskva_i_moskovskaya_oblast/kupit/kvartira/"
        
        max_pages = 5  # допустим, парсим первые 5 страниц
        # Список застройщиков для проверки
        target_developers = ["MR Group", "Группа ЛСР", "Группа «Самолет»", "ГК ФСК"]

        for p in range(1, max_pages + 1):
            # Формируем URL с аргументом page=N
            url = f"{base_url}?page={p}"
            print(f"Переходим на страницу: {url}")
            drv.get(url)

            # Дадим странице подгрузиться
            time.sleep(2)

            # Ищем карточки (по data-test="IndexPageSnippetsSnippetOffer")
            cards = drv.find_elements(
                By.CSS_SELECTOR,
                '[data-test="OffersSerpItem"]'
            )
            if not cards:
                print(f"На странице {p} не нашли карточек. Заканчиваем.")
                break

            print(f"Страница {p}: нашлось {len(cards)} карточек.")

            # Запоминаем «главную» вкладку, где сейчас список объявлений
            main_window = drv.current_window_handle

            # Перебираем карточки
            for i in range(len(cards)):
                # Т.к. при открытии новой вкладки и закрытии её
                # некоторые элементы могут «протухнуть», лучше пересобрать список.
                cards = drv.find_elements(
                    By.CSS_SELECTOR,
                    '[data-test="OffersSerpItem"]'
                )
                if i >= len(cards):
                    # Защита, если карточек стало меньше
                    break

                c = cards[i]

                # Ищем ссылку внутри карточки (чаще всего <a>)
                try:
                    link_el = c.find_element(By.CSS_SELECTOR, "a")
                except:
                    print("Ссылка в карточке не найдена. Пропускаем.")
                    continue

                # Очищаем логи запросов selenium-wire (чтобы не копить)
                drv.requests.clear()

                # Кликаем - предполагаем, что откроется в новой вкладке
                link_el.click()
                time.sleep(2)  # даём вкладке открыться

                # Находим идентификатор новой вкладки (которая не main_window)
                all_windows = drv.window_handles
                new_tab = None
                for w in all_windows:
                    if w != main_window:
                        new_tab = w
                        break

                if not new_tab:
                    # Если новая вкладка не появилась, пропускаем
                    print("Не появилась новая вкладка, возможно ссылка открылась в той же.")
                    # Если в той же — тогда нужна другая логика (без switch_to.window).
                    # Для примера пропустим эту карточку.
                    continue

                # Переключаемся на новую вкладку
                drv.switch_to.window(new_tab)

                # Ждём чуть-чуть, чтобы успели отправиться сетевые запросы
                time.sleep(3)

                # Ищем запрос "map-nearby-suggestions"
                for req in drv.requests:
                    if req.response and "map-nearby-suggestions" in req.url:
                        body = req.response.body
                        # Декомпрессируем Brotli, если нужно
                        try:
                            data_bytes = brotli.decompress(body)
                        except:
                            data_bytes = body  # если не Brotli

                        # Парсим JSON (если это действительно JSON)
                        try:
                            data_js = json.loads(data_bytes.decode('utf-8'))
                        except:
                            data_js = None

                        if data_js:
                            # Пробуем достать имя застройщика
                            try:
                                dept_name = (data_js["response"]["points"][0]
                                                     ["item"]["salesDepartments"][0]
                                                     ["name"])
                                # Проверяем, входим ли в список интересующих
                                if dept_name in target_developers:
                                    print(f"Страница {p}, застройщик: {dept_name} - делаем обработку...")
                                    # Здесь место для вашей дополнительной логики
                                else:
                                    print(f"Страница {p}, застройщик {dept_name} - пропускаем.")
                            except (KeyError, IndexError, TypeError):
                                print("Не удалось найти поле salesDepartments->name в JSON.")
                
                # Закрываем вкладку карточки
                drv.close()
                # Возвращаемся на вкладку со списком
                drv.switch_to.window(main_window)

            # Закончили обход карточек на странице p, переходим к следующей
            print(f"Страница {p} - обработана.")

    finally:
        drv.quit()

if __name__ == "__main__":
    scrape_yandex_realty_unified()
# Out:
# Переходим на страницу: https://realty.yandex.ru/moskva_i_moskovskaya_oblast/kupit/kvartira/?page=1
# Страница 1: нашлось 26 карточек.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Capital Group - пропускаем.
# Страница 1, застройщик ГК Основа - пропускаем.
# Страница 1, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Ташир - пропускаем.
# Страница 1, застройщик Мангазея Девелопмент - пропускаем.
# Страница 1, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик: MR Group - делаем обработку...
# Страница 1, застройщик IKON Development - пропускаем.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 1, застройщик Галс-Девелопмент - пропускаем.
# Страница 1 - обработана.
# Переходим на страницу: https://realty.yandex.ru/moskva_i_moskovskaya_oblast/kupit/kvartira/?page=2
# Страница 2: нашлось 25 карточек.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Страница 2, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Страница 2, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Страница 2, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Страница 2, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Страница 2, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Страница 2, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик D'oro Mille - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Страница 2, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик D'oro Mille - пропускаем.
# Страница 2, застройщик: Группа ЛСР - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Страница 2, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик D'oro Mille - пропускаем.
# Страница 2, застройщик: Группа ЛСР - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Страница 2, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик D'oro Mille - пропускаем.
# Страница 2, застройщик: Группа ЛСР - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Capital Group - пропускаем.
# Страница 2, застройщик ГК Основа - пропускаем.
# Страница 2, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Ташир - пропускаем.
# Страница 2, застройщик Мангазея Девелопмент - пропускаем.
# Страница 2, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик: MR Group - делаем обработку...
# Страница 2, застройщик IKON Development - пропускаем.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Страница 2, застройщик Level Group - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Страница 2, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик TEKTA GROUP - пропускаем.
# Страница 2, застройщик ГК «Основа» - пропускаем.
# Страница 2, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 2, застройщик D'oro Mille - пропускаем.
# ...
# Страница 3, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Capital Group - пропускаем.
# Страница 3, застройщик ГК Основа - пропускаем.
# Страница 3, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ГК Ташир - пропускаем.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Страница 3, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик: MR Group - делаем обработку...
# Страница 3, застройщик IKON Development - пропускаем.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Страница 3, застройщик Level Group - пропускаем.
# Страница 3, застройщик Touch - пропускаем.
# Страница 3, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик TEKTA GROUP - пропускаем.
# Страница 3, застройщик ГК «Основа» - пропускаем.
# Страница 3, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик D'oro Mille - пропускаем.
# Страница 3, застройщик: Группа ЛСР - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Застройщик ГК «Пионер» - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Страница 3, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Capital Group - пропускаем.
# Страница 3, застройщик ГК Основа - пропускаем.
# Страница 3, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ГК Ташир - пропускаем.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Страница 3, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик: MR Group - делаем обработку...
# Страница 3, застройщик IKON Development - пропускаем.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Страница 3, застройщик Level Group - пропускаем.
# Страница 3, застройщик Touch - пропускаем.
# Страница 3, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик TEKTA GROUP - пропускаем.
# Страница 3, застройщик ГК «Основа» - пропускаем.
# Страница 3, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик D'oro Mille - пропускаем.
# Страница 3, застройщик: Группа ЛСР - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Застройщик ГК «Пионер» - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Страница 3, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик: MR Group - делаем обработку...
# Страница 3, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Capital Group - пропускаем.
# Страница 3, застройщик ГК Основа - пропускаем.
# Страница 3, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ГК Ташир - пропускаем.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Страница 3, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик: MR Group - делаем обработку...
# Страница 3, застройщик IKON Development - пропускаем.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Страница 3, застройщик Level Group - пропускаем.
# Страница 3, застройщик Touch - пропускаем.
# Страница 3, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик TEKTA GROUP - пропускаем.
# Страница 3, застройщик ГК «Основа» - пропускаем.
# Страница 3, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик D'oro Mille - пропускаем.
# Страница 3, застройщик: Группа ЛСР - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Застройщик ГК «Пионер» - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Страница 3, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик: MR Group - делаем обработку...
# Страница 3, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Capital Group - пропускаем.
# Страница 3, застройщик ГК Основа - пропускаем.
# Страница 3, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ГК Ташир - пропускаем.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Страница 3, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик: MR Group - делаем обработку...
# Страница 3, застройщик IKON Development - пропускаем.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Страница 3, застройщик Level Group - пропускаем.
# Страница 3, застройщик Touch - пропускаем.
# Страница 3, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик TEKTA GROUP - пропускаем.
# Страница 3, застройщик ГК «Основа» - пропускаем.
# Страница 3, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик D'oro Mille - пропускаем.
# Страница 3, застройщик: Группа ЛСР - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Застройщик ГК «Пионер» - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Страница 3, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик: MR Group - делаем обработку...
# Страница 3, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик СЗ «Спартак» - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ПИК - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Capital Group - пропускаем.
# Страница 3, застройщик ГК Основа - пропускаем.
# Страница 3, застройщик: MR Group - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ГК Ташир - пропускаем.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Страница 3, застройщик G3 Group - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик: MR Group - делаем обработку...
# Страница 3, застройщик IKON Development - пропускаем.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик ГК Основа - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Страница 3, застройщик Level Group - пропускаем.
# Страница 3, застройщик Touch - пропускаем.
# Страница 3, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Галс-Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик TEKTA GROUP - пропускаем.
# Страница 3, застройщик ГК «Основа» - пропускаем.
# Страница 3, застройщик СЗ ТРЕТИЙ РИМ - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик D'oro Mille - пропускаем.
# Страница 3, застройщик: Группа ЛСР - делаем обработку...
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Застройщик ГК «Пионер» - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик Мангазея Девелопмент - пропускаем.
# Страница 3, застройщик Sminex - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик: MR Group - делаем обработку...
# Страница 3, застройщик Touch - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# Страница 3, застройщик СЗ «Спартак» - пропускаем.
# Не удалось найти поле salesDepartments->name в JSON.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 146
#     143         drv.quit()
#     145 if __name__ == "__main__":
# --> 146     scrape_yandex_realty_unified()
#
# Cell In[40], line 104, in scrape_yandex_realty_unified()
#     101 time.sleep(3)
#     103 # Ищем запрос "map-nearby-suggestions"
# --> 104 for req in drv.requests:
#     105     if req.response and "map-nearby-suggestions" in req.url:
#     106         body = req.response.body
#
# File ~/Projects/mlcore/.venv/lib/python3.11/site-packages/seleniumwire/inspect.py:26, in InspectRequestsMixin.requests(self)
#      14 @property
#      15 def requests(self) -> List[Request]:
#      16     """Retrieves the requests made between the browser and server.
#      17
#      18     Captured requests can be cleared with 'del', e.g:
#    (...)
#      24         between the browser and server.
#      25     """
# ---> 26     return self.backend.storage.load_requests()
#
# File ~/Projects/mlcore/.venv/lib/python3.11/site-packages/seleniumwire/storage.py:173, in RequestStorage.load_requests(self)
#     170 loaded = []
#     172 for indexed_request in index:
# --> 173     request = self._load_request(indexed_request.id)
#     175     if request is not None:
#     176         loaded.append(request)
#
# File ~/Projects/mlcore/.venv/lib/python3.11/site-packages/seleniumwire/storage.py:198, in RequestStorage._load_request(self, request_id)
#     195 try:
#     196     # Attach the response if there is one.
#     197     with open(os.path.join(request_dir, 'response'), 'rb') as res:
# --> 198         response = self._unpickle(res)
#     200         if response is not None:
#     201             request.response = response
#
# File ~/Projects/mlcore/.venv/lib/python3.11/site-packages/seleniumwire/storage.py:219, in RequestStorage._unpickle(self, f)
#     214 """Unpickle the object specified by the file f.
#     215
#     216 If unpickling fails return None.
#     217 """
#     218 try:
# --> 219     return pickle.load(f)
#     220 except Exception:
#     221     # Errors may sometimes occur with unpickling - e.g.
#     222     # sometimes data hasn't been fully flushed to disk
#     223     # by the OS by the time we come to unpickle it.
#     224     if log.isEnabledFor(logging.DEBUG):
#
# KeyboardInterrupt:

# %%
# -*- coding: utf-8 -*-

import time
import brotli
import json
import pandas as pd
import logging

from seleniumwire import webdriver
from selenium.webdriver.common.by import By

# Настраиваем логирование
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s"
)

def scrape_yandex_realty_pages_to_csv():
    """
    1) Идём по страницам (?page=N).
    2) На каждой странице собираем карточки (OffersSerpItem).
    3) Кликаем на каждую, парсим JSON (map-nearby-suggestions).
    4) При любых ошибках (парсинга, индексов, отсутствия полей) логируем,
       но продолжаем работать.
    5) В конце сохраняем все собранные (даже частичные) данные в CSV.
    """

    options = webdriver.ChromeOptions()
    # options.add_argument("--headless")  # для работы без открытия окна
    drv = webdriver.Chrome(seleniumwire_options={}, options=options)

    all_data = []

    try:
        base_url = "https://realty.yandex.ru/moskva_i_moskovskaya_oblast/kupit/kvartira/novostroyki/"
        max_pages = 100

        logging.info("Стартуем парсинг новостроек...")

        for page_num in range(1, max_pages + 1):
            url = f"{base_url}?page={page_num}"
            logging.info(f"Загружаем страницу №{page_num}: {url}")

            # Очищаем запросы Selenium Wire перед каждой новой страницей
            drv.requests.clear()

            try:
                drv.get(url)
                time.sleep(1)  # небольшая пауза на загрузку

                cards = drv.find_elements(By.CSS_SELECTOR, '[data-test="OffersSerpItem"]')
                if not cards:
                    logging.info(f"На стр.{page_num} карточек не найдено. Завершаем цикл.")
                    break

                logging.info(f"Стр.{page_num}: карточек={len(cards)}")

                main_window = drv.current_window_handle

                # Перебираем карточки
                for i, c in enumerate(cards, start=1):
                    # Перед обработкой карточки очистим requests
                    drv.requests.clear()

                    try:
                        link_el = c.find_element(By.CSS_SELECTOR, "a")
                    except Exception as ex_link:
                        logging.warning(f"Стр.{page_num}, карт.{i}: не нашли ссылку - {ex_link}")
                        continue

                    try:
                        link_el.click()
                        time.sleep(2)

                        all_windows = drv.window_handles
                        # Если открылась новая вкладка
                        if len(all_windows) > 1:
                            new_tab = next((w for w in all_windows if w != main_window), None)
                            if new_tab:
                                drv.switch_to.window(new_tab)
                                time.sleep(1)
                            else:
                                logging.warning(f"Стр.{page_num}, карт.{i}: нет новой вкладки.")
                                continue

                        # Парсим JSON
                        apt_data = {}
                        success = False

                        for req in drv.requests:
                            if req.response and "map-nearby-suggestions" in req.url:
                                raw_body = req.response.body
                                # Brotli
                                try:
                                    raw_body = brotli.decompress(raw_body)
                                except:
                                    pass
                                # JSON
                                try:
                                    js = json.loads(raw_body.decode("utf-8"))
                                except:
                                    js = None

                                if not js:
                                    continue

                                try:
                                    item = js["response"]["points"][0]["item"]
                                    apt_data["offerId"] = item.get("offerId", "")
                                    # Застройщик
                                    sales_depart = item.get("salesDepartments", [{}])[0]
                                    apt_data["developer"] = sales_depart.get("name", "")

                                    # Площади, комнаты
                                    apt_data["area"]       = item.get("area",{}).get("value")
                                    apt_data["livingArea"] = item.get("livingSpace",{}).get("value")
                                    apt_data["rooms"]      = item.get("roomsTotal")

                                    floors = item.get("floorsOffered",[])
                                    apt_data["floor"]       = floors[0] if floors else None
                                    apt_data["floorsTotal"] = item.get("floorsTotal")

                                    # Цена
                                    pr = item.get("price",{})
                                    apt_data["price"]      = pr.get("value")
                                    apt_data["pricePerM2"] = pr.get("valuePerPart")

                                    # Здание
                                    bld = item.get("building",{})
                                    apt_data["yearBuilt"]     = bld.get("builtYear")
                                    apt_data["quarterBuilt"]  = bld.get("builtQuarter")
                                    apt_data["buildingType"]  = bld.get("buildingType")
                                    imp = bld.get("improvements",{})
                                    apt_data["parking"]  = imp.get("PARKING",False)
                                    apt_data["lift"]     = imp.get("LIFT",False)
                                    apt_data["security"] = imp.get("SECURITY",False)

                                    # Локация
                                    loc = item.get("location",{})
                                    apt_data["address"] = loc.get("geocoderAddress","")
                                    pt = loc.get("point",{})
                                    apt_data["latitude"]  = pt.get("latitude")
                                    apt_data["longitude"] = pt.get("longitude")

                                    # Метро
                                    mt = loc.get("metro",{})
                                    apt_data["metroName"]      = mt.get("name")
                                    apt_data["metroTime"]      = mt.get("timeToMetro")
                                    apt_data["metroTransport"] = mt.get("metroTransport")

                                    # Инфраструктура
                                    apt_data["parksCount"] = len(loc.get("parks",[]))
                                    apt_data["pondsCount"] = len(loc.get("ponds",[]))
                                    apt_data["metroStationsCount"] = len(loc.get("metroList",[]))

                                    # Ценовая история
                                    apt_data["hasPriceHistory"] = pr.get("hasPriceHistory",False)
                                    apt_data["pricePrev"]       = pr.get("previous")

                                    # Прогноз окупаемости
                                    heatmaps = loc.get("allHeatmaps",[])
                                    profit = next((h for h in heatmaps if h.get("name")=="profitability"),{})
                                    apt_data["profitabilityDesc"]  = profit.get("description")
                                    apt_data["profitabilityLevel"] = profit.get("level")

                                    success = True

                                except Exception as ex_item:
                                    logging.error(f"Стр.{page_num}, карт.{i}: ошибка извлечения JSON: {ex_item}")

                                break  # закончили искать нужный request

                        if success:
                            all_data.append(apt_data)
                        else:
                            logging.warning(f"Стр.{page_num}, карт.{i}: не удалось собрать данные.")

                    except Exception as ex_card:
                        logging.error(f"Стр.{page_num}, карт.{i}: сбой при клике/парсинге - {ex_card}")

                    finally:
                        # Возвращаемся
                        if len(drv.window_handles) > 1:
                            drv.close()
                            drv.switch_to.window(main_window)
                        else:
                            drv.back()
                            time.sleep(1)

            except Exception as ex_page:
                logging.error(f"Ошибка при работе со стр.{page_num}: {ex_page}")
                # Переходим к следующей странице, несмотря на ошибку
                continue

        logging.info("Парсинг завершён. Формируем DataFrame.")
        df = pd.DataFrame(all_data)
        df.drop_duplicates(subset=["offerId"], inplace=True)

        out_file = "yandex_realty_data.csv"
        df.to_csv(out_file, index=False, encoding="utf-8")
        logging.info(f"Сохранено {len(df)} объявлений в {out_file}.")

    finally:
        drv.quit()


if __name__ == "__main__":
    scrape_yandex_realty_pages_to_csv()
# Out:
# 2025-03-04 10:41:59,859 [INFO] Using default request storage
# 2025-03-04 10:41:59,951 [INFO] Created proxy listening on ::ffff:127.0.0.1:58379
# 2025-03-04 10:42:04,289 [INFO] Capturing request: http://clients2.google.com/time/1/current?cup2key=8:jWbAER1PWwxbTGuT7khkQKB-Rk5p2-uxlKy3F_yfTkU&cup2hreq=e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# 2025-03-04 10:42:04,512 [INFO] Стартуем парсинг новостроек...
# 2025-03-04 10:42:04,513 [INFO] Загружаем страницу №1: https://realty.yandex.ru/moskva_i_moskovskaya_oblast/kupit/kvartira/novostroyki/?page=1
# 2025-03-04 10:42:05,768 [INFO] Capturing request: https://accounts.google.com/ListAccounts?gpsia=1&source=ChromiumBrowser&json=standard
# 2025-03-04 10:42:05,828 [INFO] Capturing response: https://accounts.google.com/ListAccounts?gpsia=1&source=ChromiumBrowser&json=standard 200
# 2025-03-04 10:42:05,869 [INFO] Capturing request: https://realty.yandex.ru/moskva_i_moskovskaya_oblast/kupit/kvartira/novostroyki/?page=1
# 2025-03-04 10:42:07,384 [INFO] Capturing response: https://realty.yandex.ru/moskva_i_moskovskaya_oblast/kupit/kvartira/novostroyki/?page=1 200
# 2025-03-04 10:42:08,679 [INFO] Capturing request: https://yastatic.net/s3/home/fonts/ys/1/text-regular.woff2
# 2025-03-04 10:42:08,681 [INFO] Capturing request: https://yastatic.net/s3/home/fonts/ys/1/text-medium.woff2
# 2025-03-04 10:42:08,683 [INFO] Capturing request: https://yastatic.net/react/18.2.0/react-with-dom.min.js
# 2025-03-04 10:42:08,820 [INFO] Capturing response: https://yastatic.net/s3/home/fonts/ys/1/text-regular.woff2 200
# 2025-03-04 10:42:08,832 [INFO] Capturing response: https://yastatic.net/s3/home/fonts/ys/1/text-medium.woff2 200
# 2025-03-04 10:42:08,837 [INFO] Capturing response: https://yastatic.net/react/18.2.0/react-with-dom.min.js 200
# 2025-03-04 10:42:08,946 [INFO] Capturing request: https://yastatic.net/s3/realty-front-deploy/build-static/realty-mf-footer/_/index.client.d75c3d8eb56fb55f3221.css
# 2025-03-04 10:42:08,949 [INFO] Capturing request: https://yastatic.net/s3/realty-front-deploy/build-static/realty-front-desktop/_/search.vertis-react.f38d3e26c8884594707d.css
# 2025-03-04 10:42:08,954 [INFO] Capturing request: https://yastatic.net/s3/realty-front-deploy/build-static/realty-front-desktop/_/search.client.f9877a37bc73e1cd3260.css
# 2025-03-04 10:42:08,966 [INFO] Capturing response: https://yastatic.net/s3/realty-front-deploy/build-static/realty-mf-footer/_/index.client.d75c3d8eb56fb55f3221.css 200
# 2025-03-04 10:42:08,970 [INFO] Capturing response: https://yastatic.net/s3/realty-front-deploy/build-static/realty-front-desktop/_/search.vertis-react.f38d3e26c8884594707d.css 200
# 2025-03-04 10:42:09,081 [INFO] Capturing request: https://yastatic.net/s3/realty-front-deploy/build-static/realty-front-desktop/_/search.SearchFiltersModal.949f89afa6c06102fa24.css
# 2025-03-04 10:42:09,086 [INFO] Capturing request: https://yastatic.net/s3/home/fonts/ys/1/text-bold.woff2
# 2025-03-04 10:42:09,092 [INFO] Capturing response: https://yastatic.net/s3/realty-front-deploy/build-static/realty-front-desktop/_
D0%B4%D0%BD%D0%B8%D0%BA%D0%BE%D0%B2%D0%B0%D1%8F%20%D1%83%D0%BB%D0%B8%D1%86%D0%B0%20%E2%80%94%20id%205227696985604446145&t=gdpr(3-0)clc(0-0-0)mtb(0)rqnt(1)aw(0)rcm(1)yu(8943921171741074130)pe(1)cdl(na)eco(42672644)cs(3)efid(1)ti(1)
# 2025-03-04 10:43:32,256 [INFO] Capturing response: https://vk.com/js/api/openapi.js?168 302
# 2025-03-04 10:43:32,272 [INFO] Capturing response: https://avatars.mds.yandex.net/get-realty-offers/13999248/58b42042-03c5-460e-b188-0d79c7deff98/app_large 200
# 2025-03-04 10:43:32,281 [INFO] Capturing request: https://realty.yandex.ru/gate/stat/card/?crc=8b691519fccfa0cf623eaf14c7b04780ab4aa0f1%3A1741074205
# 2025-03-04 10:43:32,311 [INFO] Capturing response: https://yandex.ru/ads/system/context.js 200
# 2025-03-04 10:43:32,316 [INFO] Capturing request: https://avatars.mds.yandex.net/get-realty-offers/14326156/7f796d62-314c-4f1d-a007-d9440a019c24/app_large
# 2025-03-04 10:43:32,334 [INFO] Capturing request: https://avatars.mds.yandex.net/get-realty-offers/12719313/a43cce02-3180-418b-925c-224b20c404e8/app_large
# 2025-03-04 10:43:32,460 [INFO] Capturing response: https://avatars.mds.yandex.net/get-realty-offers/13805905/09786354-8b5f-4c1b-809b-559c442ed280/app_large 200
# 2025-03-04 10:43:32,465 [INFO] Capturing request: https://mc.yandex.ru/webvisor/2119876?wv-part=16&wv-type=7&wmode=0&wv-hit=745149813&page-url=https%3A%2F%2Frealty.yandex.ru%2Fmoskva_i_moskovskaya_oblast%2Fkupit%2Fkvartira%2Fnovostroyki%2F%3Fpage%3D1&rn=693827311&browser-info=we%3A1%3Aet%3A1741074212%3Aw%3A1200x654%3Av%3A1613%3Az%3A180%3Ai%3A20250304104332%3Au%3A1741074142896712251%3Avf%3A14pwap7gbnncs44tf8xglmzmddy7%3Ast%3A1741074212&t=gdpr(8-0)ti(1)
# 2025-03-04 10:43:32,471 [INFO] Capturing request: https://mc.yandex.ru/metrika/metrika_match.html
# 2025-03-04 10:43:32,490 [INFO] Capturing response: https://avatars.mds.yandex.net/get-realty-offers/13999248/3583bfa7-be6a-42eb-8f34-eea00c31cd0e/app_large 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 208
#     204         drv.quit()
#     207 if __name__ == "__main__":
# --> 208     scrape_yandex_realty_pages_to_csv()
#
# Cell In[50], line 90, in scrape_yandex_realty_pages_to_csv()
#      87 apt_data = {}
#      88 success = False
# ---> 90 for req in drv.requests:
#      91     if req.response and "map-nearby-suggestions" in req.url:
#      92         raw_body = req.response.body
#
# File ~/Projects/mlcore/.venv/lib/python3.11/site-packages/seleniumwire/inspect.py:26, in InspectRequestsMixin.requests(self)
#      14 @property
#      15 def requests(self) -> List[Request]:
#      16     """Retrieves the requests made between the browser and server.
#      17
#      18     Captured requests can be cleared with 'del', e.g:
#    (...)
#      24         between the browser and server.
#      25     """
# ---> 26     return self.backend.storage.load_requests()
#
# File ~/Projects/mlcore/.venv/lib/python3.11/site-packages/seleniumwire/storage.py:173, in RequestStorage.load_requests(self)
#     170 loaded = []
#     172 for indexed_request in index:
# --> 173     request = self._load_request(indexed_request.id)
#     175     if request is not None:
#     176         loaded.append(request)
#
# File ~/Projects/mlcore/.venv/lib/python3.11/site-packages/seleniumwire/storage.py:197, in RequestStorage._load_request(self, request_id)
#     193     request.ws_messages = ws_messages
#     195 try:
#     196     # Attach the response if there is one.
# --> 197     with open(os.path.join(request_dir, 'response'), 'rb') as res:
#     198         response = self._unpickle(res)
#     200         if response is not None:
#
# KeyboardInterrupt:
